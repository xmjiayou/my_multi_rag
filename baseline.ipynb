# %%
#!unzip -n datas/财报数据库.zip -d datas/

# %%
#!pip install -r requirements.txt

# %%
#!python fitz_pipeline_all.py

# %%
# !python mineru_pipeline_all.py
# Out:
# Traceback (most recent call last):
#   File "/mnt/workspace/gpu/spark_multi_rag/mineru_pipeline_all.py", line 198, in <module>
#     main()
#   File "/mnt/workspace/gpu/spark_multi_rag/mineru_pipeline_all.py", line 190, in main
#     parse_all_pdfs(datas_dir, content_dir)
#   File "/mnt/workspace/gpu/spark_multi_rag/mineru_pipeline_all.py", line 13, in parse_all_pdfs
#     from mineru_parse_pdf import do_parse
#   File "/mnt/workspace/gpu/spark_multi_rag/mineru_parse_pdf.py", line 9, in <module>
#     from mineru.cli.common import convert_pdf_bytes_to_bytes_by_pypdfium2, prepare_env, read_fn
# ModuleNotFoundError: No module named 'mineru'

# %%
# !python rag_from_page_chunks.py
# Out:
# 加载所有页chunk...
# Traceback (most recent call last):
#   File "/mnt/workspace/gpu/spark_multi_rag/rag_from_page_chunks.py", line 160, in <module>
#     rag.setup()
#   File "/mnt/workspace/gpu/spark_multi_rag/rag_from_page_chunks.py", line 71, in setup
#     chunks = self.loader.load_chunks()
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/workspace/gpu/spark_multi_rag/rag_from_page_chunks.py", line 20, in load_chunks
#     with open(self.json_path, 'r', encoding='utf-8') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/workspace/gpu/spark_multi_rag/all_pdf_page_chunks.json'
